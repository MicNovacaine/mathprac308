# %%
import numpy as np
x=np.ones((10,3))
y=np.random.rand(10, 3)
x=x/2
a=y-x
np.min(a,axis=1) + 0.5
# Out:
# array([0.23619927, 0.10388074, 0.48179538, 0.00157595, 0.00295864,
#        0.10167577, 0.13604525, 0.02951944, 0.4822242 , 0.52817244])

# %% [markdown]
# Задача 2

# %%
x=np.random.rand(6, 6)
np.sum(x,axis=1)/np.min(x,axis=0)
# Out:
# array([  24.57556654,   49.18330554, 1897.49897929,   16.92595655,
#          38.28876704,   26.20610269])

# %% [markdown]
# Задача 3

# %%
x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0])
t=np.delete(x,-1)
mask = t == 0
x = np.delete(x, 0)
print(max(x[mask]))
# Out:
# 5

# %% [markdown]
# Задача 4 (не придумал)

# %%
x = np.ones(10)
i = np.array([0, 1, 2, 3, 5, 5, 5, 8])
j=np.ones(i.size)
t=np.vstack((i,j))
mask=t
x[mask[0]]=x[mask[0]]+1
print(x)

# %% [markdown]
# Задача 5

# %%
import numpy as np
url = 'https://raw.githubusercontent.com/sharmaroshan/Clustering-of-Mall-Customers/master/Mall_Customers.csv'
import matplotlib.pyplot as plt
data = np.loadtxt(url, delimiter=',', dtype=object, skiprows=1)
data[:, 1] = data[:, 1] == 'Male'
data = data.astype(float)
data=data[:,1:]
def distE(point1,point2):
    x=(point1-point2)**2
    return (sum(x))**(1/2)
def kmeans(obs, k, iter = 40, thresh = 1e-05):
    al=obs.size
    args=obs[0].size
    dat=al//args
    centre=obs[:k].copy()
    disp=np.ones((k,args))
    own=np.ones(dat)
    for z in range(iter):
        clon=disp.copy()
        for i in range(dat):
            s=10000
            for j in range(k):
                if distE(obs[i],centre[j]) <s:
                    s=distE(obs[i],centre[j])
                    own[i]=j
        for j in range(k):
            mask=own==j
            centre[j]=np.mean(obs[mask],axis=0)
            disp[j]=np.std(obs[mask],axis=0)
        if np.sum((clon-disp)**2)<thresh:
            break
    print(disp)
    print(np.mean(disp,axis=0))
    cs=cm.rainbow(own**2)#попытка сформировать столбец цветов принадлежности к кластеру (1)
    print(cs)
    return np.column_stack([obs,cs])#добавляю цвета к матрице
x=kmeans(data,5)
# Out:
# [[ 0.48804227 12.93783303  7.72029951 12.73104061]
#  [ 0.48804227  5.15726221  7.72029951 10.71295878]
#  [ 0.4992278  11.33578405 16.15785843 10.06196082]
#  [ 0.49851852  3.68053679 16.10199248  9.24365198]
#  [ 0.49318379 16.37394494  8.65535891  6.20266081]]
# [ 0.49340293  9.8970722  11.27116177  9.7904546 ]
# [[5.0000000e-01 0.0000000e+00 1.0000000e+00 1.0000000e+00]
#  [1.0000000e+00 1.2246468e-16 6.1232340e-17 1.0000000e+00]
#  [5.0000000e-01 0.0000000e+00 1.0000000e+00 1.0000000e+00]
#  [1.0000000e+00 1.2246468e-16 6.1232340e-17 1.0000000e+00]
#  [5.0000000e-01 0.0000000e+00 1.0000000e+00 1.0000000e+00]
#  [1.0000000e+00 1.2246468e-16 6.1232340e-17 1.0000000e+00]
#  [5.0000000e-01 0.0000000e+00 1.0000000e+00 1.0000000e+00]
#  [1.0000000e+00 1.2246468e-16 6.1232340e-17 1.0000000e+00]
#  [5.0000000e-01 0.0000000e+00 1.0000000e+00 1.0000000e+00]
#  [1.0000000e+00 1.2246468e-16 6.1232340e-17 1.0000000e+00]
#  [5.0000000e-01 0.0000000e+00 1.0000000e+00 1.0000000e+00]
# ...

# %% [markdown]
# Задача 6 ((1) не получился-разным кластерам даёт 1 цвет)

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.scatter(x[:, 1], x[:, 3],c=x[:,4])
plt.xlabel('Age')
plt.ylabel('Spending Score')
# Out:
# Text(0,0.5,'Spending Score')

# %%
plt.scatter(data[:, 1], data[:, 2],color=col)
plt.xlabel('Age')
plt.ylabel('Annual Income')
# Out:
# Text(0,0.5,'Annual Income')

# %%
plt.scatter(data[:, 2], data[:, 3],color=col)
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
# Out:
# Text(0,0.5,'Spending Score')
